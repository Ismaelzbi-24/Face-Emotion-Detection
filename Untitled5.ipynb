# %% [markdown]
# <a href="https://colab.research.google.com/github/MuneerHussain01/Face-Emotion-Detection/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
img = cv2.imread('happyboy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.5/105.5 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 12.4 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=3d56e8faff343d6b06bafb017cc1ff1aa36a921e7917450830e5a3e5cfe21ed7
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
# Out:
# 24-06-12 16:40:57 - Directory /root/.deepface created
# 24-06-12 16:40:57 - Directory /root/.deepface/weights created

# %%
predictions = DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-06-12 16:40:59 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
#   0%|          | 0.00/5.98M [00:00<?, ?B/s]
#  18%|█▊        | 1.05M/5.98M [00:00<00:00, 7.96MB/s]
#  44%|████▍     | 2.62M/5.98M [00:00<00:00, 11.3MB/s]
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 15.7MB/s]
# Action: age:  25%|██▌       | 1/4 [00:21<01:05, 21.79s/it]
# 24-06-12 16:41:20 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   0%|          | 1.05M/539M [00:00<01:08, 7.90MB/s]
#   0%|          | 2.62M/539M [00:00<00:47, 11.2MB/s]
# ...

# %%
predictions
# Out:
# [{'emotion': {'angry': 4.497719141571821e-08,
#    'disgust': 1.796745345957135e-13,
#    'fear': 0.0021548985387198627,
#    'happy': 99.5726466178894,
#    'sad': 0.42514391243457794,
#    'surprise': 4.0799142198011396e-05,
#    'neutral': 9.891790142546597e-06},
#   'dominant_emotion': 'happy',
#   'region': {'x': 0,
#    'y': 0,
#    'w': 300,
#    'h': 200,
#    'left_eye': None,
#    'right_eye': None},
#   'face_confidence': 0,
#   'age': 37,
#   'gender': {'Woman': 14.404033124446869, 'Man': 85.59597134590149},
#   'dominant_gender': 'Man',
#   'race': {'asian': 6.319866329431534,
#    'indian': 7.855036109685898,
#    'black': 55.42950630187988,
#    'white': 11.690617352724075,
#    'middle eastern': 3.6063112318515778,
#    'latino hispanic': 15.098665654659271},
#   'dominant_race': 'black'}]

# %%
type(predictions)    #pics show multipe face , so showing a list
# Out:
# list

# %%
#predictions['dominant_emotions']    for a single face

# %%
if isinstance(predictions, list):
  for prediction in predictions:
    print(prediction['dominant_emotion'])
else:
  print(predictions['dominant_emotion'])
# Out:
# happy

# %% [markdown]
# draw a rectangle across a face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

faces = faceCascade.detectMultiScale(gray, 1.1, 4)
# draw a rectangle around a faces

for(x, y, w, h) in faces:
  cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
#using puttext() methos for inserting text on videos

cv2.putText(img,
            predictions['dominant_emotion'],
            (0, 50),
            font, 1,
            (0, 0, 255),
            2,
            cv2.LINE_4);


plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a18fb2a8579d> in <cell line: 4>()
#       3
#       4 cv2.putText(img,
# ----> 5             predictions['dominant_emotion'],
#       6             (0, 50),
#       7             font, 1,
#
# TypeError: list indices must be integers or slices, not str

# %%
if isinstance(predictions, list):
    # Loop through each detected face
    for i, prediction in enumerate(predictions):
        emotion = prediction['dominant_emotion']

        # For demonstration, just place text at a different height for each face
        # In practice, you'd want to place the text near the detected face's position
        #using puttext() methos for inserting text on videos

        cv2.putText(img,
                    emotion,
                    (10, 50 + i * 50),  # Adjust the position as needed
                    font, 1,
                    (0, 0, 255),
                    2,
                    cv2.LINE_4)
else:
    # If it's a single dictionary
    emotion = predictions['dominant_emotion']
    cv2.putText(img,
                emotion,
                (10, 50),
                font, 1,
                (0, 0, 255),
                2,
                cv2.LINE_4)

# Convert BGR image to RGB for displaying with matplotlib
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
img = cv2.imread('sadw.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img, enforce_detection=False)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  6.26it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 0.4200368653982878,
#    'disgust': 2.692642988048489e-22,
#    'fear': 0.1155077712610364,
#    'happy': 7.384948208510878e-07,
#    'sad': 99.4305431842804,
#    'surprise': 3.373482482943446e-10,
#    'neutral': 0.0339063088176772},
#   'dominant_emotion': 'sad',
#   'region': {'x': 25,
#    'y': -36,
#    'w': 363,
#    'h': 363,
#    'left_eye': (276, 104),
#    'right_eye': (202, 252)},
#   'face_confidence': 0.9,
#   'age': 31,
#   'gender': {'Woman': 89.81500267982483, 'Man': 10.18499955534935},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 2.3421457037329674,
#    'indian': 14.138145744800568,
#    'black': 0.4027711693197489,
#    'white': 22.553449869155884,
#    'middle eastern': 20.937764644622803,
#    'latino hispanic': 39.625728130340576},
#   'dominant_race': 'latino hispanic'}]

# %%
# Ensure you have the necessary packages installed
# !pip install deepface opencv-python-headless opencv-python

import cv2
import numpy as np
from deepface import DeepFace
from google.colab.patches import cv2_imshow
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def capture_image():
    js = Javascript('''
        async function captureImage() {
            const video = document.createElement('video');
            const stream = await navigator.mediaDevices.getUserMedia({ video: true });

            document.body.appendChild(video);
            video.style.display = 'none';
            video.srcObject = stream;
            await video.play();

            // Resize video
            video.width = 320;
            video.height = 240;

            // Capture frame
            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            const context = canvas.getContext('2d');
            context.drawImage(video, 0, 0, canvas.width, canvas.height);

            // Stop video
            stream.getTracks().forEach(track => track.stop());
            video.remove();

            return canvas.toDataURL('image/png');
        }

        captureImage();
    ''')
    display(js)
    data_url = eval_js('captureImage()')
    header, encoded = data_url.split(',', 1)
    data = b64decode(encoded)
    img_array = np.frombuffer(data, dtype=np.uint8)
    return cv2.imdecode(img_array, cv2.IMREAD_COLOR)

# Load the pre-trained face detector from OpenCV (Haar Cascade)
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

while True:
    # Capture an image
    img = capture_image()

    # Analyze the image to find the dominant emotion
    try:
        result = DeepFace.analyze(img, actions=['emotion'], enforce_detection=False)
        emotion = result[0]['dominant_emotion'] if isinstance(result, list) else result['dominant_emotion']
    except Exception as e:
        print(f"Error analyzing frame: {e}")
        emotion = "N/A"

    # Convert the frame to grayscale for face detection
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    # Loop over the detected faces and draw rectangles around them
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Set font for text
    font = cv2.FONT_HERSHEY_SIMPLEX

    # Put the dominant emotion text on the frame
    cv2.putText(img,
                emotion,
                (50, 50),
                font, 3,
                (0, 0, 255),
                2,
                cv2.LINE_4)

    # Display the frame
    cv2_imshow(img)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# ...
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=RGB size=640x480>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-bd76f845645e> in <cell line: 53>()
#      53 while True:
#      54     # Capture an image
# ---> 55     img = capture_image()
#      56
#      57     # Analyze the image to find the dominant emotion
#
# <ipython-input-28-bd76f845645e> in capture_image()
#      42     ''')
#      43     display(js)
# ---> 44     data_url = eval_js('captureImage()')
#      45     header, encoded = data_url.split(',', 1)
#      46     data = b64decode(encoded)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
# ...

# %%
pip install flask opencv-python-headless deepface

# %%
pip install flask-ngrok

# %%
from flask_ngrok import run_with_ngrok

from flask import Flask, render_template, Response, request
import cv2
from deepface import DeepFace
import numpy as np
import base64
import pickle

app = Flask(__name__)

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def analyze_frame(frame):
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        emotion = result[0]['dominant_emotion'] if isinstance(result, list) else result['dominant_emotion']
    except Exception as e:
        print(f"Error analyzing frame: {e}")
        emotion = "N/A"
    return emotion

@app.route('/')
def index():
    return render_template('index.html')

@app.route('/video_feed', methods=['POST'])
def video_feed():
    data = request.json['image']
    img_data = base64.b64decode(data.split(',')[1])
    np_img = np.frombuffer(img_data, dtype=np.uint8)
    frame = cv2.imdecode(np_img, cv2.IMREAD_COLOR)

    emotion = analyze_frame(frame)

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, emotion, (50, 50), font, 1, (0, 0, 255), 2, cv2.LINE_4)

    _, buffer = cv2.imencode('.jpg', frame)
    response = base64.b64encode(buffer).decode('utf-8')
    return {'image': response}

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
